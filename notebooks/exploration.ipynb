# %%
import pandas as pd
from pathlib import Path

df = pd.read_csv("/workspaces/LOL_Draft_Assistant/data/processed/match_features_15_20_1.csv")
print(df.columns.tolist())
print(df.head(3))
# Out:
# ['Blue_attackrange_mean', 'Blue_attackrange_max', 'Blue_attackrange_min', 'Blue_attackrange_std', 'Blue_cc_score_mean', 'Blue_cc_score_max', 'Blue_cc_score_min', 'Blue_cc_score_std', 'Blue_engage_score_mean', 'Blue_engage_score_max', 'Blue_engage_score_min', 'Blue_engage_score_std', 'Blue_peel_score_mean', 'Blue_peel_score_max', 'Blue_peel_score_min', 'Blue_peel_score_std', 'Blue_zone_control_score_mean', 'Blue_zone_control_score_max', 'Blue_zone_control_score_min', 'Blue_zone_control_score_std', 'Blue_mobility_score_mean', 'Blue_mobility_score_max', 'Blue_mobility_score_min', 'Blue_mobility_score_std', 'Blue_magic_ratio_mean', 'Blue_magic_ratio_max', 'Blue_magic_ratio_min', 'Blue_magic_ratio_std', 'Blue_physical_ratio_mean', 'Blue_physical_ratio_max', 'Blue_physical_ratio_min', 'Blue_physical_ratio_std', 'Blue_damage_mix_mean', 'Blue_damage_mix_max', 'Blue_damage_mix_min', 'Blue_damage_mix_std', 'Blue_hp_mean', 'Blue_hp_max', 'Blue_hp_min', 'Blue_hp_std', 'Blue_armor_mean', 'Blue_ar
# ...
